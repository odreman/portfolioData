# %% [markdown]
# # Análisis Exploratorio: Dataset de Airbnb

# %% [markdown]
# ## Objetivos
#
# El objetivo de este análisis es responder preguntas específicas sobre un dataset real de Airbnb, aplicando técnicas de exploración y análisis de datos.

# %% [markdown]
# ## Configuración del entorno

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Carga de los datos
# Como en otras ocasiones cargaremos los datos de un fichero csv.

# %%
df = pd.read_csv('dataset_airbnb_madrid.csv')

# %% [markdown]
# Una vez cargados los datos debemos inspeccionarlos, antes de empezar nuestro análisis.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13335 entries, 0 to 13334
# Data columns (total 95 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                13335 non-null  int64
#  1   listing_url                       13335 non-null  object
#  2   scrape_id                         13335 non-null  int64
#  3   last_scraped                      13335 non-null  object
#  4   name                              13335 non-null  object
#  5   summary                           12846 non-null  object
#  6   space                             9700 non-null   object
#  7   description                       13329 non-null  object
#  8   experiences_offered               13335 non-null  object
#  9   neighborhood_overview             8308 non-null   object
#  10  notes                             5037 non-null   object
#  11  transit                           8264 non-null   object
#  12  access                            7546 non-null   object
#  13  interaction                       7522 non-null   object
#  14  house_rules                       8666 non-null   object
#  15  thumbnail_url                     10847 non-null  object
#  16  medium_url                        10847 non-null  object
#  17  picture_url                       13335 non-null  object
#  18  xl_picture_url                    10847 non-null  object
#  19  host_id                           13335 non-null  int64
#  20  host_url                          13335 non-null  object
#  21  host_name                         13332 non-null  object
#  22  host_since                        13332 non-null  object
#  23  host_location                     13293 non-null  object
#  24  host_about                        8282 non-null   object
#  25  host_response_time                11622 non-null  object
#  26  host_response_rate                11622 non-null  object
#  27  host_acceptance_rate              0 non-null      float64
#  28  host_is_superhost                 13332 non-null  object
#  29  host_thumbnail_url                13332 non-null  object
#  30  host_picture_url                  13332 non-null  object
#  31  host_neighbourhood                9983 non-null   object
#  32  host_listings_count               13332 non-null  float64
#  33  host_total_listings_count         13332 non-null  float64
#  34  host_verifications                13332 non-null  object
#  35  host_has_profile_pic              13332 non-null  object
#  36  host_identity_verified            13332 non-null  object
#  37  street                            13335 non-null  object
#  38  neighbourhood                     8772 non-null   object
#  39  neighbourhood_cleansed            13335 non-null  object
#  40  neighbourhood_group_cleansed      13335 non-null  object
#  41  city                              13333 non-null  object
#  42  state                             13292 non-null  object
#  43  zipcode                           12896 non-null  object
#  44  market                            13285 non-null  object
#  45  smart_location                    13335 non-null  object
#  46  country_code                      13335 non-null  object
#  47  country                           13334 non-null  object
#  48  latitude                          13335 non-null  float64
#  49  longitude                         13335 non-null  float64
#  50  is_location_exact                 13335 non-null  object
#  51  property_type                     13335 non-null  object
#  52  room_type                         13335 non-null  object
#  53  accommodates                      13335 non-null  int64
#  54  bathrooms                         13285 non-null  float64
#  55  bedrooms                          13312 non-null  float64
#  56  beds                              13286 non-null  float64
#  57  bed_type                          13335 non-null  object
#  58  amenities                         13335 non-null  object
#  59  square_feet                       522 non-null    float64
#  60  price                             13335 non-null  object
#  61  weekly_price                      3512 non-null   object
#  62  monthly_price                     3324 non-null   object
#  63  security_deposit                  5731 non-null   object
#  64  cleaning_fee                      7851 non-null   object
#  65  guests_included                   13335 non-null  int64
#  66  extra_people                      13335 non-null  object
#  67  minimum_nights                    13335 non-null  int64
#  68  maximum_nights                    13335 non-null  int64
#  69  calendar_updated                  13335 non-null  object
#  70  has_availability                  0 non-null      float64
#  71  availability_30                   13335 non-null  int64
#  72  availability_60                   13335 non-null  int64
#  73  availability_90                   13335 non-null  int64
#  74  availability_365                  13335 non-null  int64
#  75  calendar_last_scraped             13335 non-null  object
#  76  number_of_reviews                 13335 non-null  int64
#  77  first_review                      10542 non-null  object
#  78  last_review                       10541 non-null  object
#  79  review_scores_rating              10417 non-null  float64
#  80  review_scores_accuracy            10399 non-null  float64
#  81  review_scores_cleanliness         10405 non-null  float64
#  82  review_scores_checkin             10389 non-null  float64
#  83  review_scores_communication       10405 non-null  float64
#  84  review_scores_location            10387 non-null  float64
#  85  review_scores_value               10387 non-null  float64
#  86  requires_license                  13335 non-null  object
#  87  license                           249 non-null    object
#  88  jurisdiction_names                0 non-null      float64
#  89  instant_bookable                  13335 non-null  object
#  90  cancellation_policy               13335 non-null  object
#  91  require_guest_profile_picture     13335 non-null  object
#  92  require_guest_phone_verification  13335 non-null  object
#  93  calculated_host_listings_count    13335 non-null  int64
#  94  reviews_per_month                 10542 non-null  float64
# dtypes: float64(19), int64(13), object(63)
# memory usage: 9.7+ MB

# %%
df.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0   7830063   https://www.airbnb.com/rooms/7830063  20170407214119
# 1   9898596   https://www.airbnb.com/rooms/9898596  20170407214119
# 2  15334645  https://www.airbnb.com/rooms/15334645  20170407214119
# 3   1307795   https://www.airbnb.com/rooms/1307795  20170407214119
# 4  17410608  https://www.airbnb.com/rooms/17410608  20170407214119
#
#   last_scraped                                          name  \
# 0   2017-04-08                     Quiet room in Plaza Mayor
# 1   2017-04-08       Homely apartment in the heart of Madrid
# 2   2017-04-08   Piso Muy Luminoso en pleno centro de Madrid
# 3   2017-04-08              Rent room in the heart of Madrid
# 4   2017-04-08  Luxury duplex penthouse in historic building
#
#                                              summary  \
# 0  Room in magnificent property in the historic c...
# 1  Spacious apartment for up to 10 people, with a...
# 2  Lugares de interés: Casa Lucio, Cine Doré, Cal...
# 3                                                NaN
# 4  Amazing duplex penthouse in a historic buildin...
#
#                                                space  \
# 0  Based in the historic center of Madrid, to 1 m...
# 1  This spacious apartment is located in the cent...
# 2  Lo mejor es su ubicación en pleno centro de Ma...
# 3  Very nice room , whith private bath , in a bea...
# 4  It is located in an emblematic building with e...
#
#                                          description experiences_offered  \
# 0  Room in magnificent property in the historic c...                none
# 1  Spacious apartment for up to 10 people, with a...                none
# 2  Lugares de interés: Casa Lucio, Cine Doré, Cal...                none
# 3  Very nice room , whith private bath , in a bea...                none
# 4  Amazing duplex penthouse in a historic buildin...                none
#
#                                neighborhood_overview  \
# 0  In the historic heart of Madrid, near the Plaz...
# 1  The Living Santa Ana Apartments are located in...
# 2  La zona de la Latina es un área cultural y un ...
# 3                                                NaN
# 4  "Madrid de los Austrias "is a beautiful neighb...
#
#                                                notes  \
# 0  Check-in from 21:00 to 23:00 has an extra char...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Situado en pleno corazón del Madrid más histór...
#
#                                              transit  \
# 0  Very well connected by buses and subwa (Tirso ...
# 1          We are 3m walk from the La Latina subway.
# 2  Por Metro se llega rápidamente en la Línea 5, ...
# 3                                                NaN
# 4  El piso está situado a 300 metros de la parada...
#
#                                               access  \
# 0  Quiet room on the first floor of historic buil...
# 1                                                NaN
# 2  El apartamento está a disposición de los huésp...
# 3                                                NaN
# 4    All elements in my flat are available to guests
#
#                                          interaction  \
# 0  Maps and all kind of information and recommend...
# 1  During his stay, please contact us if you have...
# 2  Estamos siempre disponibles a través del teléf...
# 3                                                NaN
# 4   I will be happy to help you whenever you need it
#
#                                          house_rules  \
# 0  Please respect the silence of the other guests...
# 1  The apartment is located in a community of nei...
# 2                                                NaN
# 3                                                NaN
# 4  Piso adecuado para parejas, familias o amigos,...
#
#                                        thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/99669989/f...
# 1  https://a0.muscache.com/im/pictures/f3336e14-5...
# 2  https://a0.muscache.com/im/pictures/0f339adf-b...
# 3  https://a0.muscache.com/im/pictures/19716668/b...
# 4  https://a0.muscache.com/im/pictures/268edf49-c...
#
#                                           medium_url  \
# 0  https://a0.muscache.com/im/pictures/99669989/f...
# 1  https://a0.muscache.com/im/pictures/f3336e14-5...
# 2  https://a0.muscache.com/im/pictures/0f339adf-b...
# 3  https://a0.muscache.com/im/pictures/19716668/b...
# 4  https://a0.muscache.com/im/pictures/268edf49-c...
#
#                                          picture_url  \
# 0  https://a0.muscache.com/im/pictures/99669989/f...
# 1  https://a0.muscache.com/im/pictures/f3336e14-5...
# 2  https://a0.muscache.com/im/pictures/0f339adf-b...
# 3  https://a0.muscache.com/im/pictures/19716668/b...
# 4  https://a0.muscache.com/im/pictures/268edf49-c...
#
#                                       xl_picture_url   host_id  \
# 0  https://a0.muscache.com/im/pictures/99669989/f...  41032693
# 1  https://a0.muscache.com/im/pictures/f3336e14-5...  50908516
# 2  https://a0.muscache.com/im/pictures/0f339adf-b...  97753616
# 3  https://a0.muscache.com/im/pictures/19716668/b...   1877614
# 4  https://a0.muscache.com/im/pictures/268edf49-c...   9885245
#
#                                      host_url    host_name  host_since  \
# 0  https://www.airbnb.com/users/show/41032693  Bluekitchen  2015-08-10
# 1  https://www.airbnb.com/users/show/50908516       Daniel  2015-12-09
# 2  https://www.airbnb.com/users/show/97753616         Will  2016-10-03
# 3   https://www.airbnb.com/users/show/1877614        Fabio  2012-03-07
# 4   https://www.airbnb.com/users/show/9885245        Jorge  2013-11-08
#
#                         host_location  \
# 0  Madrid, Community of Madrid, Spain
# 1  Madrid, Community of Madrid, Spain
# 2  Madrid, Community of Madrid, Spain
# 3               Madrid, Madrid, Spain
# 4  Madrid, Community of Madrid, Spain
#
#                                           host_about host_response_time  \
# 0  Somos dos amigos de la infancia de Madrid que ...     within an hour
# 1  Somos Amanda y Dani, tenemos este establecimie...     within an hour
# 2  Mi nombre es Will, Venezolano, vivo en Madrid,...     within an hour
# 3    Se habla , frances , ingles, italiano , español     within an hour
# 4                                                NaN     within an hour
#
#   host_response_rate  host_acceptance_rate host_is_superhost  \
# 0               100%                   NaN                 f
# 1               100%                   NaN                 f
# 2                94%                   NaN                 t
# 3               100%                   NaN                 t
# 4               100%                   NaN                 f
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/users/41032693/prof...
# 1  https://a0.muscache.com/im/pictures/0061d173-a...
# 2  https://a0.muscache.com/im/pictures/548b727a-d...
# 3  https://a0.muscache.com/im/users/1877614/profi...
# 4  https://a0.muscache.com/im/users/9885245/profi...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/41032693/prof...          La Latina
# 1  https://a0.muscache.com/im/pictures/0061d173-a...          La Latina
# 2  https://a0.muscache.com/im/pictures/548b727a-d...          La Latina
# 3  https://a0.muscache.com/im/users/1877614/profi...                NaN
# 4  https://a0.muscache.com/im/users/9885245/profi...          Hortaleza
#
#    host_listings_count  host_total_listings_count  \
# 0                  7.0                        7.0
# 1                  1.0                        1.0
# 2                  1.0                        1.0
# 3                  1.0                        1.0
# 4                 13.0                       13.0
#
#                           host_verifications host_has_profile_pic  \
# 0     ['email', 'phone', 'reviews', 'jumio']                    t
# 1     ['email', 'phone', 'reviews', 'jumio']                    t
# 2              ['email', 'phone', 'reviews']                    t
# 3  ['email', 'phone', 'facebook', 'reviews']                    t
# 4     ['email', 'phone', 'reviews', 'jumio']                    t
#
#   host_identity_verified                                             street  \
# 0                      t  La Latina, Madrid, Comunidad de Madrid 28005, ...
# 1                      t  La Latina, Madrid, Comunidad de Madrid 28005, ...
# 2                      f  La Latina, Madrid, Comunidad de Madrid 28005, ...
# 3                      f           Madrid, Community of Madrid 28013, Spain
# 4                      t  La Latina, Madrid, Comunidad de Madrid 28005, ...
#
#   neighbourhood neighbourhood_cleansed neighbourhood_group_cleansed    city  \
# 0     La Latina                Palacio                       Centro  Madrid
# 1     La Latina                Palacio                       Centro  Madrid
# 2     La Latina                Palacio                       Centro  Madrid
# 3           NaN                Palacio                       Centro  Madrid
# 4     La Latina                Palacio                       Centro  Madrid
#
#                  state zipcode  market smart_location country_code country  \
# 0  Comunidad de Madrid   28005  Madrid  Madrid, Spain           ES   Spain
# 1  Comunidad de Madrid   28005  Madrid  Madrid, Spain           ES   Spain
# 2  Comunidad de Madrid   28005  Madrid  Madrid, Spain           ES   Spain
# 3  Community of Madrid   28013  Madrid  Madrid, Spain           ES   Spain
# 4  Comunidad de Madrid   28005  Madrid  Madrid, Spain           ES   Spain
#
#     latitude  longitude is_location_exact property_type        room_type  \
# 0  40.412275  -3.708718                 t         House     Private room
# 1  40.411093  -3.708985                 t     Apartment  Entire home/apt
# 2  40.413587  -3.708945                 t     Apartment  Entire home/apt
# 3  40.419936  -3.709180                 f     Apartment     Private room
# 4  40.410894  -3.712537                 t     Apartment  Entire home/apt
#
#    accommodates  bathrooms  bedrooms  beds  bed_type  \
# 0             2        2.0       1.0   2.0  Real Bed
# 1            10        1.0       3.0   9.0  Real Bed
# 2             2        1.0       1.0   1.0  Real Bed
# 3             2        1.0       1.0   1.0  Real Bed
# 4             4        1.5       2.0   2.0  Real Bed
#
#                                            amenities  square_feet    price  \
# 0  {TV,Internet,"Wireless Internet",Kitchen,Doorm...          NaN   $42.00
# 1  {TV,Internet,"Wireless Internet","Wheelchair a...          NaN  $135.00
# 2  {TV,"Wireless Internet","Air conditioning",Kit...          NaN   $81.00
# 3  {TV,Internet,"Wireless Internet","Air conditio...          0.0   $43.00
# 4  {TV,Internet,"Wireless Internet","Air conditio...          NaN   $50.00
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 0      $300.00     $1,200.00          $100.00       $15.00                2
# 1          NaN           NaN          $200.00       $40.00                6
# 2          NaN           NaN              NaN       $15.00                2
# 3      $240.00       $480.00              NaN          NaN                1
# 4          NaN           NaN          $250.00       $20.00                2
#
#   extra_people  minimum_nights  maximum_nights calendar_updated  \
# 0        $0.00               2              30      2 weeks ago
# 1       $15.00               1            1125            today
# 2       $10.00               1            1125       2 days ago
# 3       $10.00               3            1125      3 weeks ago
# 4       $25.00               1            1125        yesterday
#
#    has_availability  availability_30  availability_60  availability_90  \
# 0               NaN                4               13               37
# 1               NaN                0                5               14
# 2               NaN                4               17               31
# 3               NaN                1                1               28
# 4               NaN                7               34               59
#
#    availability_365 calendar_last_scraped  number_of_reviews first_review  \
# 0               165            2017-04-08                100   2015-08-23
# 1               230            2017-04-08                 68   2015-12-31
# 2               287            2017-04-08                 34   2016-10-08
# 3               303            2017-04-08                 11   2013-07-16
# 4               334            2017-04-08                  6   2017-02-26
#
#   last_review  review_scores_rating  review_scores_accuracy  \
# 0  2017-04-02                  92.0                     9.0
# 1  2017-04-04                  93.0                     9.0
# 2  2017-03-21                  93.0                     9.0
# 3  2017-03-06                  98.0                    10.0
# 4  2017-04-03                 100.0                    10.0
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                        9.0                   10.0
# 1                        9.0                   10.0
# 2                        9.0                    9.0
# 3                       10.0                   10.0
# 4                        9.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                    10.0                  9.0
# 1                         10.0                    10.0                  9.0
# 2                          9.0                    10.0                  9.0
# 3                         10.0                    10.0                 10.0
# 4                         10.0                    10.0                 10.0
#
#   requires_license license  jurisdiction_names instant_bookable  \
# 0                t     NaN                 NaN                t
# 1                t     NaN                 NaN                t
# 2                t     NaN                 NaN                t
# 3                t     NaN                 NaN                f
# 4                t     NaN                 NaN                f
#
#   cancellation_policy require_guest_profile_picture  \
# 0            moderate                             f
# 1            moderate                             f
# 2              strict                             f
# 3              strict                             f
# 4              strict                             f
#
#   require_guest_phone_verification  calculated_host_listings_count  \
# 0                                f                               7
# 1                                f                               1
# 2                                f                               1
# 3                                f                               1
# 4                                f                              13
#
#    reviews_per_month
# 0               5.04
# 1               4.39
# 2               5.57
# 3               0.24
# 4               4.29

# %% [markdown]
# 'id',
# 'listing_url',
# 'scrape_id',
# 'last_scraped',
# 'name',
# 'summary',
# 'space',
# 'description',
# 'experiences_offered',
# 'neighborhood_overview',
# 'notes',
# 'transit',
# 'access',
# 'interaction',
# 'house_rules',
# 'thumbnail_url',
# 'medium_url',
#     'picture_url',
#     'xl_picture_url',
# 'host_id',
# 'host_url',
# 'host_name',
# 'host_since',
# 'host_location',
# 'host_about',
# 'host_response_time',
# 'host_response_rate',
# 'host_acceptance_rate',
# 'host_is_superhost',
# 'host_thumbnail_url',
# 'host_picture_url',
# 'host_neighbourhood',
# 'host_listings_count',
# 'host_total_listings_count',
# 'host_verifications',
# 'host_has_profile_pic',
# 'host_identity_verified',
# 'street',
# 'neighbourhood',
# 'neighbourhood_cleansed',
# 'neighbourhood_group_cleansed',
# 'city',
# 'state',
# 'zipcode',
# 'market',
# 'smart_location',
# 'country_code',
# 'country',
# 'latitude',
# 'longitude',
# 'is_location_exact',
# 'property_type',
# 'room_type',
# 'accommodates',
# 'bathrooms',
# 'bedrooms',
# 'beds',
# 'bed_type',
# 'amenities',
# 'square_feet',
# 'price',
# 'weekly_price',
# 'monthly_price',
# 'security_deposit',
# 'cleaning_fee',
# 'guests_included',
# 'extra_people',
# 'minimum_nights',
# 'maximum_nights',
# 'calendar_updated',
# 'has_availability',
# 'availability_30',
# 'availability_60',
# 'availability_90',
# 'availability_365',
# 'calendar_last_scraped',
# 'number_of_reviews',
# 'first_review',
# 'last_review',
# 'review_scores_rating',
# 'review_scores_accuracy',
# 'review_scores_cleanliness',
# 'review_scores_checkin',
# 'review_scores_communication',
# 'review_scores_location',
# 'review_scores_value',
# 'requires_license',
# 'license',
# 'jurisdiction_names',
# 'instant_bookable',
# 'cancellation_policy',
# 'require_guest_profile_picture',
# 'require_guest_phone_verification',
# 'calculated_host_listings_count',
# 'reviews_per_month'

# %% [markdown]
# ## ¿Cuántos alojamientos tienen fotos?

# %%
print("Alojamientos con fotos: ", df.picture_url.count())
# Out:
# Alojamientos con fotos:  13335

# %% [markdown]
# ## ¿Cuál es el porcentaje de originalidad de las descripciones?

# %%
total_descripciones = df.description.count()
print("Total de descripciones: ", total_descripciones)

descripciones_unicas = df.description.nunique()
print("Descripciones únicas: ", descripciones_unicas)

porcentaje_originalidad = descripciones_unicas/total_descripciones*100
print("Porcentaje de originalidad de las descripciones: ", porcentaje_originalidad.round(2), "%")
# Out:
# Total de descripciones:  13329
# Descripciones únicas:  12873
# Porcentaje de originalidad de las descripciones:  96.58 %

# %% [markdown]
# ## ¿Cuántos alojamientos tiene de media cada dueño?

# %%
df.host_listings_count.describe()
# Out:
# count    13332.000000
# mean         9.777453
# std         27.812982
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          5.000000
# max        519.000000
# Name: host_listings_count, dtype: float64

# %%
#La media de alojamientos por dueño
media_alojamientos = df.host_listings_count.mean()
print(f"Número medio de alojamientos por dueño: {media_alojamientos:.2f}")
# Out:
# Número medio de alojamientos por dueño: 9.78

# %% [markdown]
# ## ¿Cuáles son los 10 dueños que más alojamientos tienen?

# %%
df_top10_host = df.sort_values(by="host_listings_count", ascending=False).head(10)
print(df_top10_host.host_name  + ": " + df_top10_host.host_listings_count.astype(int).astype(str))
# Out:
# 11246     Jason: 519
# 1339       Loic: 265
# 3730     Javier: 207
# 113      Javier: 207
# 2347     Javier: 207
# 4634     Javier: 207
# 3022     Javier: 207
# 2241     Javier: 207
# 452      Javier: 207
# 5102     Javier: 207
# dtype: object

# %% [markdown]
# ## ¿Cuántos alojamientos tiene Airbnb en Madrid?
# Tip: te recomiento que borres todos los alojamientos que no estén en Madrid y luego los cuentes.

# %%
df[["city", "country"]].value_counts()
# Out:
# city                                 country
# Madrid                               Spain      13191
# 马德里                                  Spain         52
# Madrid, Comunidad de Madrid, ES      Spain         20
# Madrid                               Spain         15
# madrid                               Spain          8
# Pozuelo de Alarcón                   Spain          4
#                                      Spain          3
# 馬德里                                  Spain          2
# Motilla del Palancar                 Spain          2
# Pozuelo                              Spain          2
# San Fernando de Henares              Spain          2
# Chueca                               Spain          2
# San Lázaro                           Spain          1
# villa verde bajo                     Spain          1
# Onil                                 Spain          1
# Málaga                               Spain          1
# Valderrodrigo                        Spain          1
# Malaga                               Spain          1
# Madrid, Vallecas (Fontarrón)         Spain          1
# Madrid, Comunidad de Madrid, ESPANA  Spain          1
# Ventas                               Spain          1
# las matas  madrid                    Spain          1
# \nDelicias                           Spain          1
# Madid                                Spain          1
# MADRID                               Spain          1
#                                      Spain          1
#  Madrid                              Spain          1
# Aravaca                              Spain          1
# Aravaca (Madrid)                     Spain          1
# Barcelona                            Spain          1
# Boadilla del Monte                   Spain          1
# Centro                               Spain          1
# Centro, Madrid                       Spain          1
# Chiva                                Spain          1
# Chueca, Madrid                       Spain          1
# Comunidad de Madrid                  Spain          1
# Delicias-Madrid                      Spain          1
# La Elipa                             Spain          1
# La Habana                            Cuba           1
# MADRID                               Spain          1
# Madri                                Spain          1
# Name: count, dtype: int64

# %%
# Según google esto: 馬德里 y 马德里 es madrid

# Definir ciudades que no son Madrid
ciudades_no_madrid = [
    'Barcelona', 
    'Málaga', 
    'Malaga', 
    'Chiva', 
    'Onil', 
    'La Habana', 
    'Motilla del Palancar',
]

# Crear una copia limpia del DataFrame
df_madrid = df.copy()

# Limpiar la columna city de manera más exhaustiva
df_madrid['city'] = (df_madrid['city']
    .fillna('')                      
    .astype(str)                     # Convertir todo a string
    .str.strip()                     # Eliminar espacios al inicio y final
)

# Filtrar el DataFrame
df_madrid = df_madrid[
    # Eliminar filas con ciudad vacía, espacios o longitud cero
    (df_madrid['city'] != '') & 
    (df_madrid['city'] != ' ') & 
    (df_madrid['city'].str.len() > 0) &
    # Eliminar las ciudades no deseadas
    (~df_madrid['city'].isin(ciudades_no_madrid))
]

# Verificar el resultado con ambas columnas
print(df_madrid[["city", "country"]].value_counts())

# Nota: no soy de España, por lo que se me puede haber pasado algún error.
# Out:
# city                                 country
# Madrid                               Spain      13207
# 马德里                                  Spain         52
# Madrid, Comunidad de Madrid, ES      Spain         20
# madrid                               Spain          8
# Pozuelo de Alarcón                   Spain          4
# 馬德里                                  Spain          2
# Chueca                               Spain          2
# MADRID                               Spain          2
# San Fernando de Henares              Spain          2
# Pozuelo                              Spain          2
# Madrid, Vallecas (Fontarrón)         Spain          1
# villa verde bajo                     Spain          1
# las matas  madrid                    Spain          1
# Ventas                               Spain          1
# Valderrodrigo                        Spain          1
# San Lázaro                           Spain          1
# Boadilla del Monte                   Spain          1
# Madrid, Comunidad de Madrid, ESPANA  Spain          1
# Centro                               Spain          1
# Aravaca (Madrid)                     Spain          1
# Madri                                Spain          1
# Madid                                Spain          1
# La Elipa                             Spain          1
# Delicias-Madrid                      Spain          1
# Delicias                             Spain          1
# Comunidad de Madrid                  Spain          1
# Chueca, Madrid                       Spain          1
# Centro, Madrid                       Spain          1
# Aravaca                              Spain          1
# Name: count, dtype: int64

# %%
# Cuantos alojamientos hay en Madrid?
print("Alojamientos en Madrid: ", df_madrid.city.count())
# Out:
# Alojamientos en Madrid:  13321

# %% [markdown]
# ## ¿Cuántos alojamientos requieren licencia?

# %%
# Contar alojamientos que requieren licencia en Madrid
alojamientos_requieren_licencia = df_madrid[df_madrid['requires_license'] == 't'].shape[0]
print(f"Alojamientos que requieren licencia: {alojamientos_requieren_licencia}")

# Para verificar también los que no requieren en Madrid
#alojamientos_que_no_requieren_licencia = df_madrid[df_madrid['requires_license'] == 'f'].shape[0]
#print(f"Alojamientos que NO requieren licencia: {alojamientos_que_no_requieren_licencia}")
# Out:
# Alojamientos que requieren licencia: 13320

# %% [markdown]
# ## ¿Cuántos alojamientos que requieren licencia realmente la tienen?

# %%
#Está dificil responder esta pregunta, ya que en el campo license hay que hacer limpieza de los datos

# Ver los datos de la columna license
df_madrid['license'].value_counts()
# Out:
# license
# VT1046                                                                                   3
# VT-2043                                                                                  2
# VT411                                                                                    2
# VT1003                                                                                   2
# VT746                                                                                    2
# B87667465                                                                                2
# VT 1002                                                                                  2
# VT-2114                                                                                  1
# VT281                                                                                    1
# VT-1445                                                                                  1
# VT-1831                                                                                  1
# En tramitación                                                                           1
# VT-1969                                                                                  1
# VT206                                                                                    1
# VT-724                                                                                   1
# VT-519                                                                                   1
# VT-26                                                                                    1
# VT-290                                                                                   1
# VT-1968                                                                                  1
# VT 249                                                                                   1
# VT-1996                                                                                  1
# VT1945                                                                                   1
# VT569                                                                                    1
# VT-275                                                                                   1
# VT207                                                                                    1
# VT-716                                                                                   1
# VT-1881                                                                                  1
# VT-1407                                                                                  1
# VT 758                                                                                   1
# VT 1637                                                                                  1
# VT-342                                                                                   1
# VT-2335                                                                                  1
# VT1964                                                                                   1
# VT-1406                                                                                  1
# VT-1152                                                                                  1
# VT-2128                                                                                  1
# VT-1178                                                                                  1
# VT-3                                                                                     1
# VT-2065                                                                                  1
# VT-1391                                                                                  1
# 0999602156403235221819                                                                   1
# VT-279                                                                                   1
# 2017/0120709                                                                             1
# VT-1521                                                                                  1
# VT-1180                                                                                  1
# VT-1179                                                                                  1
# VT-80                                                                                    1
# VT-1182                                                                                  1
# VT-821                                                                                   1
# VT-2195                                                                                  1
# Apartamento de Uso Turstico VT-1106                                                      1
# 0981659233846140390244                                                                   1
# VT-2341                                                                                  1
# VT-78                                                                                    1
# VT-1519                                                                                  1
# VT-1710                                                                                  1
# VT-20                                                                                    1
# VT-722                                                                                   1
# VT-1411                                                                                  1
# VT-723                                                                                   1
# VT-824                                                                                   1
# VT-1877                                                                                  1
# VT-383                                                                                   1
# VT-1832                                                                                  1
# VT-2330                                                                                  1
# VT-2386                                                                                  1
# VT-1873                                                                                  1
# VT 208                                                                                   1
# 3566712                                                                                  1
# VT-219                                                                                   1
# 4437209                                                                                  1
# VT-1107                                                                                  1
# VT-1977                                                                                  1
# VT-1635                                                                                  1
# 03/078803.9/17                                                                           1
# VT-1512                                                                                  1
# 50111329x                                                                                1
# VT1031                                                                                   1
# VT-1903                                                                                  1
# En la comunidad de Madrid no es necesario registro o inscripción para esta actividad.    1
# VT-1506                                                                                  1
# VT 1963                                                                                  1
# VT-2050                                                                                  1
# VT 804                                                                                   1
# 03/432068.9/16                                                                           1
# EBM961777484                                                                             1
# B82957895                                                                                1
# VT 1153                                                                                  1
# VT-1114                                                                                  1
# No necesita                                                                              1
# Registered as Housing for tourist use VT-2236 in the Community of Madrid                 1
# Competitividad turística ref. 03/332883.9/16                                             1
# VT1962                                                                                   1
# VT-2052                                                                                  1
# VT-2051                                                                                  1
# VT-1036                                                                                  1
# VT-1949                                                                                  1
# VT-1335                                                                                  1
# VT-273                                                                                   1
# e                                                                                        1
# VT-1410                                                                                  1
# VT-2040                                                                                  1
# VT-17                                                                                    1
# Registro de entrada: Ref: 49/171273.9/14                                                 1
# VT-2183                                                                                  1
# VT 1720                                                                                  1
# VT-1978                                                                                  1
# VT-1513                                                                                  1
# VT-1981                                                                                  1
# VT-1900                                                                                  1
# B81657595                                                                                1
# VT378                                                                                    1
# 03/434447.9/16                                                                           1
# VT-19                                                                                    1
# VT-2056                                                                                  1
# VT-1403                                                                                  1
# REF 03/035858.9/17                                                                       1
# VT-2116                                                                                  1
# VT 1452                                                                                  1
# VT-1598                                                                                  1
# VT-1203                                                                                  1
# VT-945                                                                                   1
# VT-266                                                                                   1
# VT-1082                                                                                  1
# 03/027713.9/17                                                                           1
# VT-1389                                                                                  1
# Vivienda registrada  VT-714                                                              1
# VT-1552                                                                                  1
# VT-1957                                                                                  1
# VT-2069                                                                                  1
# VT1732                                                                                   1
# VT-2255                                                                                  1
# VT-1520                                                                                  1
# VT-59                                                                                    1
# VT-1781                                                                                  1
# VT-1824                                                                                  1
# VT-521                                                                                   1
# VT-1836                                                                                  1
# VT-38                                                                                    1
# Registro de empresas Turisticas  número de inscripción referencia VT-1435                1
# VT. 1000                                                                                 1
# VT-2279                                                                                  1
# VT-1376                                                                                  1
# VT-1692                                                                                  1
# VT-1515                                                                                  1
# VT-1943                                                                                  1
# VT-1307                                                                                  1
# VT-1079                                                                                  1
# VT-2042                                                                                  1
# VT679                                                                                    1
# VT-2041                                                                                  1
# VT-1072                                                                                  1
# VT-2266                                                                                  1
# VT-1833                                                                                  1
# VT-1511                                                                                  1
# VT - 1727                                                                                1
# VT-257                                                                                   1
# Registro de entrada 03/046097.9/17                                                       1
# VT-260                                                                                   1
# VT250                                                                                    1
# VT-261                                                                                   1
# VT1946                                                                                   1
# VT1195                                                                                   1
# VT-2073                                                                                  1
# VT-1694                                                                                  1
# VT 2070                                                                                  1
# VT2111                                                                                   1
# VT - 2184                                                                                1
# VT-1070                                                                                  1
# 03/778860.9/17                                                                           1
# VT-1341                                                                                  1
# VT1835                                                                                   1
# VT 1324                                                                                  1
# VT 1422                                                                                  1
# Registro de Entrada 03/313144                                                            1
# VT-1636                                                                                  1
# VT-2191                                                                                  1
# VT1944                                                                                   1
# VT-2101                                                                                  1
# VT 1012                                                                                  1
# VT-258                                                                                   1
# VT-81                                                                                    1
# H28391AAX3C                                                                              1
# VT-281                                                                                   1
# Trámites                                                                                 1
# VT1883                                                                                   1
# VT2045                                                                                   1
# VT-520                                                                                   1
# VT-477                                                                                   1
# VT 743                                                                                   1
# VT-1105                                                                                  1
# VT-1104                                                                                  1
# VT -1448                                                                                 1
# VT-1802                                                                                  1
# VT-1578                                                                                  1
# VT-592                                                                                   1
# VT-475                                                                                   1
# VT - 185                                                                                 1
# "Santa Isabel Vintage"  nº registro:  03/033598.9/17                                     1
# VT-1436                                                                                  1
# VT-1514                                                                                  1
# VT-2182                                                                                  1
# VT-1010                                                                                  1
# VT-944                                                                                   1
# VT-1612                                                                                  1
# VT-296                                                                                   1
# RF. 03/055040.9/17                                                                       1
# VT-79                                                                                    1
# VT-2117                                                                                  1
# VT-1793                                                                                  1
# VT-1925                                                                                  1
# VT-476                                                                                   1
# VT-2305                                                                                  1
# VT-2187                                                                                  1
# VT-1557                                                                                  1
# VT 72                                                                                    1
# VT 2433                                                                                  1
# VT2215                                                                                   1
# VT-2167                                                                                  1
# VT-1954                                                                                  1
# VT-220                                                                                   1
# Vivienda registrada VT-659                                                               1
# VT - 1525                                                                                1
# 03/448896.9/16                                                                           1
# VT2257                                                                                   1
# 09/004101.9/15                                                                           1
# VT-218                                                                                   1
# VT-1719                                                                                  1
# VT-1408                                                                                  1
# VT-297                                                                                   1
# VT-2162                                                                                  1
# VT-2346                                                                                  1
# VT-1780                                                                                  1
# VT-2061                                                                                  1
# VT-1644                                                                                  1
# VT-316                                                                                   1
# VT-1632                                                                                  1
# VT - 1855                                                                                1
# VT 1626                                                                                  1
# VT-2450                                                                                  1
# VT343                                                                                    1
# Name: count, dtype: int64

# %%
# 1. Crear la nueva columna
df_madrid['license_clean'] = ''

# 2. Procesar todas las licencias que contienen VT
mask_vt = df_madrid['license'].str.contains('VT', na=False)
for idx, row in df_madrid[mask_vt].iterrows():
    texto = row['license']
    inicio = texto.find('VT')
    if inicio != -1:
        # Extraer desde VT hasta el final
        texto_limpio = texto[inicio:]
        
        # Eliminar todos los caracteres que no sean números, excepto VT
        numeros = ''.join(c for c in texto_limpio if c.isdigit())
        if numeros:  # si encontramos números
            texto_limpio = f"VT-{numeros}"
            df_madrid.at[idx, 'license_clean'] = texto_limpio



# Encontrar casos donde license tiene valor pero license_clean está vacío
licencias_sin_limpiar = df_madrid[
    (df_madrid['license'].notna()) & 
    (df_madrid['license'] != '') &
    (df_madrid['license_clean'] == '')
]

print("Licencias originales que no se limpiaron:")
print(licencias_sin_limpiar['license'].value_counts())
print(f"\nTotal de licencias sin limpiar: {len(licencias_sin_limpiar)}")
# Out:
# Licencias originales que no se limpiaron:
# license
# B87667465                                                                                2
# Registro de entrada 03/046097.9/17                                                       1
# 03/778860.9/17                                                                           1
# No necesita                                                                              1
# B82957895                                                                                1
# EBM961777484                                                                             1
# 03/432068.9/16                                                                           1
# En la comunidad de Madrid no es necesario registro o inscripción para esta actividad.    1
# 50111329x                                                                                1
# 03/078803.9/17                                                                           1
# 4437209                                                                                  1
# 3566712                                                                                  1
# REF 03/035858.9/17                                                                       1
# 03/434447.9/16                                                                           1
# B81657595                                                                                1
# Registro de entrada: Ref: 49/171273.9/14                                                 1
# e                                                                                        1
# En tramitación                                                                           1
# 0981659233846140390244                                                                   1
# 2017/0120709                                                                             1
# 0999602156403235221819                                                                   1
# 03/027713.9/17                                                                           1
# RF. 03/055040.9/17                                                                       1
# Trámites                                                                                 1
# 09/004101.9/15                                                                           1
# 03/448896.9/16                                                                           1
# "Santa Isabel Vintage"  nº registro:  03/033598.9/17                                     1
# H28391AAX3C                                                                              1
# Registro de Entrada 03/313144                                                            1
# Competitividad turística ref. 03/332883.9/16                                             1
# Name: count, dtype: int64
#
# Total de licencias sin limpiar: 31

# %%
# Contar alojamientos con licencia sin limpiar
alojamientos_con_licencia_sin_limpiar = df_madrid[
    (df_madrid['license'].notna()) & 
    (df_madrid['license'].str.strip() != '')
].shape[0]
alojamientos_con_licencia_sin_limpiar

alojamientos_con_licencia_limpias = df_madrid[
    df_madrid['license_clean'] != ''
].shape[0]
alojamientos_con_licencia_limpias

# Sin conocer los datos me es dificil seguir haciendo limpieza de los datos, creo que ninguno de los datos es correcto.
# A priori se observa que en el campo license hay datos erroneos,
# En la variable  sin_limpiar considero todo como valido en en la varieble limpio creo que me faltan otras condiciones

# En concreto, respondiendo a la pregunta:
print("Alojamientos que requieren licencia: (Madrid)" , alojamientos_requieren_licencia)
#Alojamientos que tienen licencia sin limpiar
print("Alojamientos que tienen licencia: (Madrid)" , alojamientos_con_licencia_sin_limpiar)
#Alojamientos que tienen licencia limpias
print("Alojamientos que tienen licencia: (Madrid) -limpias-" , alojamientos_con_licencia_limpias)
# Out:
# Alojamientos que requieren licencia: (Madrid) 13320
# Alojamientos que tienen licencia: (Madrid) 249
# Alojamientos que tienen licencia: (Madrid) -limpias- 218

# %% [markdown]
# ## ¿Cuántos alojamientos que requieren licencia realmente no la tienen?

# %%
#Igual que el caso anterior, considero license lleno como valido (aunque a priori no lo es)

# Alojamientos que requieren licencia pero no la tienen
alojamientos_sin_licencia = df_madrid[
    (df_madrid['requires_license'] == 't') & # Requieren licencia
    (
        (df_madrid['license'].isna()) | # No tienen licencia (NaN)
        (df_madrid['license'].str.strip() == '') # O tienen string vacío
    )
].shape[0]

print(f"Alojamientos que requieren licencia pero no la tienen: {alojamientos_sin_licencia}")

#Ahora considerando la columna license_clean que tampoco considera todos los casos por lo que podrian faltar registros
alojamientos_sin_licencia_clean = df_madrid[
    (df_madrid['requires_license'] == 't') & # Requieren licencia
    (df_madrid['license_clean'] == '') # No tienen licencia (NaN)
].shape[0]

print(f"Alojamientos que requieren licencia pero no la tienen -datos limpios-: {alojamientos_sin_licencia_clean}")
# Out:
# Alojamientos que requieren licencia pero no la tienen: 13071
# Alojamientos que requieren licencia pero no la tienen -datos limpios-: 13102

# %% [markdown]
# ## ¿Cual es el código postal con precio medio más caro de madrid?
# Tip: excluye zipcodes atípicos y arregla los zipcodes que se puedan.

# %%
#Ver los datos de la columna zipcode
df_madrid.zipcode.value_counts()
# Out:
# zipcode
# 28012           2065
# 28004           1803
# 28005           1195
# 28013           1019
# 28014            632
# 28015            600
# 28045            500
# 28010            384
# 28008            338
# 28028            264
# 28011            252
# 28001            231
# 28006            219
# 28009            217
# 28007            206
# 28019            202
# 28020            196
# 28003            186
# 28002            172
# 28039            162
# 28025            124
# 28027            124
# 28029            112
# 28017            111
# 28043            103
# 28026             93
# 28042             91
# 28033             90
# 28053             87
# 28038             79
# 28016             78
# 28035             76
# 28030             73
# 28047             67
# 28036             67
# 28037             66
# 28041             65
# 28021             61
# 28050             58
# 28034             49
# 28024             44
# 28018             43
# 28023             37
# 28032             33
# 28046             32
# 28022             30
# 28031             27
# 28040             20
# 28044             20
# 28051             18
# 28054             13
# 28055             12
# 28049              4
# 28830              2
# 28058              1
# 28048              1
# 28052              1
# 2802\n28012        1
# 28850              1
# 28                 1
# 280013             1
# 20126              1
# 28051\n28051       1
# 84084              1
# 28056              1
# Madrid 28004       1
# 2015               1
# -                  1
# 25008              1
# 20013              1
# 28002\n28002       1
# 27004              1
# 2804               1
# 28060              1
# 28290              1
# 28660              1
# 28105              1
# 2815               1
# 28094              1
#                    1
# 28730              1
# 2805               1
# 27013              1
# 28224              1
# Name: count, dtype: int64

# %%
df_madrid.zipcode.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 13321 entries, 0 to 13334
# Series name: zipcode
# Non-Null Count  Dtype
# --------------  -----
# 12882 non-null  object
# dtypes: object(1)
# memory usage: 724.2+ KB

# %%
#Ver los datos de la columna price
df_madrid.price.describe()
# Out:
# count      13321
# unique       304
# top       $50.00
# freq         614
# Name: price, dtype: object

# %%
# 1. Limpiar y convertir la columna de precios
df_madrid['price'] = (df_madrid['price']
    .str.replace('$', '')  # Quitar el símbolo $
    .str.replace(',', '')  # Quitar las comas
    .astype(float)  # Convertir a float
)
df_madrid.price.describe()
# Out:
# count    13321.000000
# mean        69.000676
# std        103.400483
# min          9.000000
# 25%         31.000000
# 50%         53.000000
# 75%         80.000000
# max       7700.000000
# Name: price, dtype: float64

# %%
# 2. Limpiar los códigos postales
def clean_zipcode(zipcode):
    if pd.isna(zipcode):
        return None
    
    # Convertir a string y limpiar espacios
    zipcode = str(zipcode).strip()
    
    # Extraer solo los números
    nums = ''.join(c for c in zipcode if c.isdigit())
    
    # Validar que sea un código postal de Madrid (28XXX)
    if len(nums) >= 5 and nums[:2] == '28':
        return int(nums[:5])  # Tomar solo los primeros 5 dígitos
    return None

df_madrid['zipcode'] = df_madrid['zipcode'].apply(clean_zipcode)

# %%
# 3. Calcular precio medio por código postal
precio_medio_por_cp = (df_madrid
    .groupby('zipcode')['price']
    .agg(['mean', 'count'])
    .round(2)
)

# 4. Filtrar solo códigos postales válidos y con suficientes muestras
precio_medio_por_cp_filtered = precio_medio_por_cp[
    (precio_medio_por_cp.index.notna()) &  # Eliminar None/NaN
    (precio_medio_por_cp['count'] > 5)  # Mínimo 5 muestras
]

# %%
# 5. Ordenar por precio medio y mostrar los top 5
print("Top 5 códigos postales más caros (con más de 5 alojamientos):")
print(precio_medio_por_cp_filtered.sort_values('mean', ascending=False).head())

# Mostrar el código postal más caro
cp_mas_caro = precio_medio_por_cp_filtered.sort_values('mean', ascending=False).iloc[0]
print(f"\nEl código postal más caro es {int(cp_mas_caro.name)} con un precio medio de {cp_mas_caro['mean']:.2f}€")
# Out:
# Top 5 códigos postales más caros (con más de 5 alojamientos):
#            mean  count
# zipcode
# 28023.0  147.95     37
# 28035.0  147.71     76
# 28040.0  132.45     20
# 28001.0  125.29    232
# 28016.0  109.14     78
#
# El código postal más caro es 28023 con un precio medio de 147.95€

# %% [markdown]
# ## ¿En que rango se mueven los precios de los alojamientos en madrid?

# %%
# Calcular estadísticas descriptivas de los precios
stats_precios = df_madrid['price'].describe(percentiles=[.05, .25, .50, .75, .95])

print("Estadísticas de precios en Madrid:")
print(f"Precio mínimo: {stats_precios['min']:.2f}€")
print(f"5% de los precios están por debajo de: {stats_precios['5%']:.2f}€")
print(f"25% de los precios están por debajo de: {stats_precios['25%']:.2f}€")
print(f"Precio medio: {stats_precios['mean']:.2f}€")
print(f"Precio mediano: {stats_precios['50%']:.2f}€")
print(f"75% de los precios están por debajo de: {stats_precios['75%']:.2f}€")
print(f"95% de los precios están por debajo de: {stats_precios['95%']:.2f}€")
print(f"Precio máximo: {stats_precios['max']:.2f}€")
# Out:
# Estadísticas de precios en Madrid:
# Precio mínimo: 9.00€
# 5% de los precios están por debajo de: 18.00€
# 25% de los precios están por debajo de: 31.00€
# Precio medio: 69.00€
# Precio mediano: 53.00€
# 75% de los precios están por debajo de: 80.00€
# 95% de los precios están por debajo de: 160.00€
# Precio máximo: 7700.00€

# %% [markdown]
# ## (extra) ¿Cuales son los 10 atributos de la columna host_verifications? ¿Cuantas ocurrencias tiene cada uno de los 10?

# %%
df_madrid.host_verifications.value_counts()
# Out:
# host_verifications
# ['email', 'phone', 'reviews']                                                                                                              3325
# ['email', 'phone', 'reviews', 'jumio']                                                                                                     3079
# ['email', 'phone', 'reviews', 'jumio', 'government_id']                                                                                     818
# ['email', 'phone', 'facebook', 'reviews', 'jumio']                                                                                          724
# ['email', 'phone', 'facebook', 'reviews']                                                                                                   693
# ['email', 'phone']                                                                                                                          549
# ['email', 'phone', 'reviews', 'jumio', 'work_email']                                                                                        380
# ['email', 'phone', 'reviews', 'jumio', 'offline_government_id', 'government_id']                                                            350
# ['email', 'phone', 'facebook', 'reviews', 'jumio', 'government_id']                                                                         323
# ['email', 'phone', 'reviews', 'work_email']                                                                                                 245
# ['email', 'phone', 'google', 'reviews', 'jumio', 'government_id']                                                                           208
# ['phone']                                                                                                                                   159
# ['email', 'phone', 'reviews', 'manual_offline', 'jumio']                                                                                    153
# ['phone', 'reviews']                                                                                                                        148
# ['email', 'phone', 'facebook']                                                                                                              145
# ['email', 'phone', 'facebook', 'reviews', 'jumio', 'offline_government_id', 'government_id']                                                120
# ['email', 'phone', 'facebook', 'reviews', 'jumio', 'work_email']                                                                            108
# ['email', 'phone', 'google', 'reviews', 'jumio']                                                                                             98
# ['email', 'phone', 'reviews', 'manual_offline']                                                                                              76
# ['email', 'phone', 'google', 'reviews']                                                                                                      69
# ['email', 'phone', 'linkedin', 'reviews', 'jumio', 'government_id']                                                                          63
# ['email', 'phone', 'reviews', 'jumio', 'government_id', 'work_email']                                                                        62
# ['email', 'phone', 'google', 'reviews', 'jumio', 'offline_government_id', 'government_id']                                                   62
# ['email', 'phone', 'google', 'jumio', 'offline_government_id', 'government_id']                                                              59
# ['email', 'reviews']                                                                                                                         54
# ['email', 'phone', 'jumio']                                                                                                                  47
# ['email', 'phone', 'facebook', 'reviews', 'manual_offline', 'jumio']                                                                         47
# ['email', 'phone', 'facebook', 'google', 'reviews', 'jumio', 'government_id']                                                                45
# ['email', 'phone', 'facebook', 'google', 'jumio', 'offline_government_id', 'government_id']                                                  41
# ['phone', 'facebook', 'reviews']                                                                                                             40
# ['email', 'phone', 'facebook', 'reviews', 'jumio', 'government_id', 'work_email']                                                            34
# ['email', 'phone', 'google', 'reviews', 'jumio', 'work_email']                                                                               33
# ['email', 'phone', 'reviews', 'kba']                                                                                                         31
# ['phone', 'facebook']                                                                                                                        29
# ['email', 'phone', 'manual_online', 'reviews', 'jumio']                                                                                      28
# ['email', 'phone', 'facebook', 'reviews', 'work_email']                                                                                      27
# ['email', 'phone', 'reviews', 'sent_id']                                                                                                     26
# ['email', 'phone', 'reviews', 'jumio', 'offline_government_id', 'government_id', 'work_email']                                               24
# ['email', 'phone', 'manual_online', 'reviews', 'manual_offline', 'jumio']                                                                    24
# ['email', 'phone', 'google', 'linkedin', 'reviews', 'jumio', 'government_id']                                                                23
# ['email', 'phone', 'facebook', 'google', 'reviews', 'jumio', 'work_email']                                                                   23
# ['email', 'phone', 'facebook', 'jumio', 'offline_government_id', 'government_id']                                                            23
# ['email', 'phone', 'facebook', 'google', 'reviews', 'jumio']                                                                                 23
# ['email', 'phone', 'google', 'reviews', 'jumio', 'government_id', 'work_email']                                                              22
# ['email', 'phone', 'facebook', 'jumio', 'government_id', 'work_email']                                                                       21
# ['email', 'phone', 'facebook', 'jumio', 'government_id']                                                                                     20
# ['email']                                                                                                                                    20
# ['email', 'phone', 'google', 'jumio', 'government_id']                                                                                       20
# ['email', 'phone', 'google', 'linkedin', 'reviews', 'jumio']                                                                                 18
# ['email', 'phone', 'facebook', 'reviews', 'kba']                                                                                             16
# ['email', 'phone', 'manual_online', 'reviews', 'manual_offline']                                                                             16
# ['email', 'phone', 'facebook', 'jumio']                                                                                                      15
# ['email', 'phone', 'work_email']                                                                                                             15
# ['email', 'phone', 'manual_online', 'reviews', 'manual_offline', 'jumio', 'work_email']                                                      15
# ['email', 'phone', 'linkedin', 'reviews', 'jumio']                                                                                           14
# ['email', 'phone', 'google', 'linkedin', 'reviews', 'jumio', 'work_email']                                                                   14
# ['email', 'phone', 'jumio', 'offline_government_id', 'government_id']                                                                        12
# ['email', 'phone', 'reviews', 'manual_offline', 'jumio', 'work_email']                                                                       12
# ['email', 'phone', 'linkedin', 'reviews', 'jumio', 'government_id', 'work_email']                                                            12
# ['email', 'phone', 'jumio', 'government_id']                                                                                                 11
# ['reviews']                                                                                                                                  11
# ['email', 'phone', 'google']                                                                                                                 11
# ['phone', 'reviews', 'jumio']                                                                                                                11
# ['phone', 'facebook', 'reviews', 'jumio', 'government_id']                                                                                   11
# ['email', 'phone', 'facebook', 'google', 'reviews']                                                                                          11
# ['email', 'phone', 'linkedin', 'reviews', 'jumio', 'offline_government_id', 'government_id']                                                 10
# ['email', 'phone', 'facebook', 'linkedin', 'reviews', 'jumio', 'government_id']                                                              10
# ['phone', 'reviews', 'jumio', 'work_email']                                                                                                  10
# ['email', 'phone', 'facebook', 'reviews', 'jumio', 'offline_government_id', 'selfie', 'government_id', 'identity_manual']                     9
# ['email', 'phone', 'facebook', 'reviews', 'manual_offline', 'jumio', 'work_email']                                                            9
# ['email', 'phone', 'reviews', 'manual_offline', 'jumio', 'sent_id']                                                                           8
# ['email', 'phone', 'reviews', 'jumio', 'offline_government_id', 'selfie', 'government_id', 'identity_manual']                                 8
# ['email', 'phone', 'facebook', 'google', 'reviews', 'jumio', 'offline_government_id', 'government_id']                                        7
# ['email', 'phone', 'facebook', 'google', 'linkedin', 'reviews', 'jumio', 'offline_government_id', 'government_id']                            7
# ['email', 'phone', 'facebook', 'google', 'linkedin', 'reviews', 'jumio', 'government_id']                                                     7
# ['email', 'facebook', 'reviews']                                                                                                              7
# ['email', 'phone', 'facebook', 'reviews', 'jumio', 'offline_government_id', 'government_id', 'work_email']                                    7
# ['email', 'reviews', 'jumio', 'government_id']                                                                                                7
# ['email', 'phone', 'reviews', 'jumio', 'sent_id']                                                                                             6
# ['email', 'phone', 'facebook', 'linkedin', 'reviews', 'jumio']                                                                                6
# []                                                                                                                                            6
# ['email', 'phone', 'google', 'reviews', 'manual_offline', 'jumio']                                                                            5
# ['email', 'phone', 'linkedin', 'reviews', 'jumio', 'offline_government_id', 'government_id', 'work_email']                                    5
# ['email', 'phone', 'jumio', 'offline_government_id', 'selfie', 'government_id', 'identity_manual']                                            5
# ['email', 'phone', 'facebook', 'google', 'linkedin', 'reviews', 'jumio']                                                                      5
# ['phone', 'reviews', 'jumio', 'government_id']                                                                                                5
# ['email', 'phone', 'linkedin', 'jumio', 'offline_government_id', 'government_id']                                                             5
# ['email', 'phone', 'facebook', 'google', 'linkedin', 'reviews', 'jumio', 'work_email']                                                        5
# ['email', 'reviews', 'jumio']                                                                                                                 5
# ['email', 'phone', 'google', 'linkedin', 'reviews', 'jumio', 'government_id', 'work_email']                                                   5
# ['email', 'phone', 'linkedin', 'reviews']                                                                                                     5
# ['email', 'phone', 'manual_online', 'facebook', 'reviews', 'jumio']                                                                           4
# ['email', 'phone', 'manual_online', 'facebook', 'reviews', 'manual_offline']                                                                  4
# ['email', 'phone', 'linkedin', 'reviews', 'work_email']                                                                                       4
# ['email', 'phone', 'facebook', 'reviews', 'manual_offline']                                                                                   4
# ['email', 'phone', 'linkedin', 'jumio', 'government_id']                                                                                      4
# ['email', 'phone', 'facebook', 'google', 'linkedin', 'reviews']                                                                               4
# ['email', 'phone', 'google', 'work_email']                                                                                                    3
# ['email', 'phone', 'google', 'reviews', 'kba', 'work_email']                                                                                  3
# ['phone', 'facebook', 'reviews', 'jumio', 'offline_government_id', 'government_id']                                                           3
# ['email', 'phone', 'manual_online', 'reviews', 'manual_offline', 'work_email']                                                                3
# ['email', 'phone', 'facebook', 'google', 'linkedin', 'reviews', 'jumio', 'government_id', 'work_email']                                       3
# ['phone', 'facebook', 'reviews', 'jumio']                                                                                                     3
# ['email', 'phone', 'facebook', 'reviews', 'jumio', 'offline_government_id', 'sent_id', 'government_id']                                       3
# ['email', 'phone', 'google', 'reviews', 'jumio', 'offline_government_id', 'government_id', 'work_email']                                      3
# ['phone', 'reviews', 'work_email']                                                                                                            3
# ['email', 'phone', 'google', 'linkedin', 'reviews']                                                                                           3
# ['phone', 'jumio', 'offline_government_id', 'selfie', 'government_id', 'identity_manual']                                                     3
# ['email', 'facebook']                                                                                                                         3
# ['email', 'phone', 'google', 'jumio']                                                                                                         3
# ['email', 'reviews', 'manual_offline', 'jumio']                                                                                               3
# ['email', 'phone', 'facebook', 'google', 'reviews', 'jumio', 'government_id', 'work_email']                                                   3
# ['phone', 'google', 'reviews', 'jumio']                                                                                                       3
# ['email', 'phone', 'facebook', 'linkedin', 'reviews']                                                                                         3
# ['email', 'phone', 'facebook', 'reviews', 'kba', 'work_email']                                                                                3
# ['phone', 'google']                                                                                                                           3
# ['phone', 'linkedin', 'reviews', 'jumio', 'government_id']                                                                                    2
# ['email', 'phone', 'facebook', 'linkedin', 'reviews', 'jumio', 'government_id', 'work_email']                                                 2
# ['email', 'phone', 'facebook', 'reviews', 'jumio', 'selfie', 'government_id', 'identity_manual']                                              2
# ['email', 'phone', 'linkedin', 'reviews', 'jumio', 'work_email']                                                                              2
# ['email', 'phone', 'manual_online', 'facebook', 'reviews', 'manual_offline', 'jumio']                                                         2
# ['email', 'phone', 'facebook', 'google', 'jumio', 'government_id']                                                                            2
# ['email', 'phone', 'facebook', 'linkedin', 'reviews', 'jumio', 'offline_government_id', 'government_id']                                      2
# ['facebook', 'reviews']                                                                                                                       2
# ['email', 'phone', 'facebook', 'jumio', 'work_email']                                                                                         2
# ['email', 'phone', 'facebook', 'google', 'linkedin', 'reviews', 'jumio', 'offline_government_id', 'government_id', 'work_email']              2
# ['email', 'phone', 'manual_online', 'facebook', 'reviews', 'manual_offline', 'work_email']                                                    2
# ['email', 'facebook', 'reviews', 'jumio', 'government_id']                                                                                    2
# ['email', 'phone', 'manual_online', 'reviews', 'manual_offline', 'jumio', 'sent_id']                                                          2
# ['email', 'phone', 'reviews', 'jumio', 'selfie', 'government_id', 'identity_manual']                                                          2
# ['email', 'phone', 'google', 'reviews', 'kba']                                                                                                2
# ['reviews', 'jumio']                                                                                                                          2
# ['email', 'phone', 'manual_online', 'facebook', 'reviews', 'manual_offline', 'jumio', 'offline_government_id', 'government_id']               2
# ['email', 'phone', 'facebook', 'work_email']                                                                                                  2
# ['email', 'phone', 'reviews', 'jumio', 'offline_government_id', 'selfie', 'government_id', 'identity_manual', 'work_email']                   2
# ['email', 'reviews', 'work_email']                                                                                                            2
# ['email', 'phone', 'facebook', 'google']                                                                                                      2
# ['email', 'phone', 'reviews', 'jumio', 'kba']                                                                                                 2
# ['phone', 'facebook', 'jumio', 'government_id']                                                                                               1
# ['email', 'manual_online', 'reviews', 'manual_offline']                                                                                       1
# ['email', 'phone', 'google', 'linkedin', 'jumio', 'government_id', 'work_email']                                                              1
# ['email', 'phone', 'reviews', 'jumio', 'kba', 'government_id']                                                                                1
# ['email', 'phone', 'google', 'jumio', 'offline_government_id', 'government_id', 'work_email']                                                 1
# ['email', 'phone', 'manual_offline']                                                                                                          1
# ['email', 'phone', 'facebook', 'linkedin', 'jumio', 'offline_government_id', 'government_id']                                                 1
# ['email', 'phone', 'manual_offline', 'jumio']                                                                                                 1
# ['phone', 'jumio']                                                                                                                            1
# ['phone', 'reviews', 'jumio', 'government_id', 'work_email']                                                                                  1
# ['email', 'phone', 'manual_online', 'google', 'reviews', 'manual_offline', 'work_email']                                                      1
# ['email', 'phone', 'jumio', 'work_email']                                                                                                     1
# ['email', 'phone', 'amex', 'reviews', 'jumio']                                                                                                1
# ['email', 'phone', 'google', 'jumio', 'government_id', 'work_email']                                                                          1
# ['email', 'phone', 'facebook', 'linkedin', 'weibo']                                                                                           1
# ['email', 'phone', 'facebook', 'google', 'linkedin', 'reviews', 'manual_offline', 'jumio']                                                    1
# ['email', 'jumio', 'offline_government_id', 'government_id']                                                                                  1
# ['email', 'phone', 'reviews', 'jumio', 'kba', 'work_email']                                                                                   1
# ['email', 'phone', 'facebook', 'google', 'linkedin', 'jumio', 'government_id']                                                                1
# ['email', 'phone', 'reviews', 'weibo', 'jumio', 'government_id']                                                                              1
# ['email', 'phone', 'facebook', 'linkedin', 'reviews', 'jumio', 'work_email']                                                                  1
# ['email', 'phone', 'google', 'linkedin', 'reviews', 'jumio', 'offline_government_id', 'government_id']                                        1
# ['phone', 'jumio', 'offline_government_id', 'government_id']                                                                                  1
# ['email', 'phone', 'google', 'linkedin', 'reviews', 'jumio', 'offline_government_id', 'government_id', 'work_email']                          1
# ['reviews', 'jumio', 'government_id']                                                                                                         1
# ['email', 'phone', 'google', 'reviews', 'jumio', 'selfie', 'government_id', 'identity_manual']                                                1
# ['email', 'phone', 'facebook', 'reviews', 'jumio', 'photographer', 'work_email']                                                              1
# ['email', 'phone', 'manual_online', 'jumio', 'government_id']                                                                                 1
# ['email', 'phone', 'facebook', 'government_id']                                                                                               1
# ['email', 'phone', 'manual_online', 'reviews', 'manual_offline', 'jumio', 'government_id']                                                    1
# ['email', 'phone', 'facebook', 'jumio', 'offline_government_id', 'government_id', 'work_email']                                               1
# ['email', 'phone', 'facebook', 'google', 'reviews', 'kba']                                                                                    1
# ['email', 'phone', 'reviews', 'manual_offline', 'jumio', 'government_id']                                                                     1
# ['email', 'phone', 'google', 'amex', 'reviews', 'jumio', 'government_id']                                                                     1
# ['email', 'phone', 'facebook', 'reviews', 'jumio', 'offline_government_id', 'selfie', 'government_id', 'identity_manual', 'work_email']       1
# ['email', 'google', 'reviews', 'jumio', 'government_id']                                                                                      1
# ['email', 'facebook', 'reviews', 'jumio', 'work_email']                                                                                       1
# ['email', 'phone', 'facebook', 'google', 'linkedin', 'jumio', 'government_id', 'identity_manual', 'work_email']                               1
# ['email', 'phone', 'facebook', 'linkedin', 'reviews', 'sent_id']                                                                              1
# ['email', 'phone', 'reviews', 'jumio', 'selfie', 'government_id', 'identity_manual', 'work_email']                                            1
# ['phone', 'facebook', 'jumio', 'offline_government_id', 'government_id']                                                                      1
# ['phone', 'linkedin', 'reviews']                                                                                                              1
# ['facebook']                                                                                                                                  1
# ['email', 'phone', 'manual_online', 'reviews', 'jumio', 'government_id']                                                                      1
# ['phone', 'reviews', 'jumio', 'offline_government_id', 'government_id']                                                                       1
# ['email', 'phone', 'facebook', 'reviews', 'jumio', 'photographer']                                                                            1
# ['email', 'phone', 'google', 'reviews', 'work_email']                                                                                         1
# ['email', 'phone', 'facebook', 'reviews', 'sent_id']                                                                                          1
# ['email', 'phone', 'reviews', 'kba', 'work_email']                                                                                            1
# ['phone', 'facebook', 'google', 'linkedin', 'reviews', 'jumio', 'government_id', 'work_email']                                                1
# ['email', 'phone', 'manual_online', 'reviews', 'manual_offline', 'sent_id']                                                                   1
# ['phone', 'facebook', 'google', 'reviews', 'jumio', 'government_id']                                                                          1
# ['email', 'google']                                                                                                                           1
# Name: count, dtype: int64

# %%
# 1. Convertir las strings de lista a listas reales y extraer los valores únicos
def extract_verifications(verification_str):
    # Quitar los corchetes y comillas
    verification_str = verification_str.strip('[]')
    # Separar por comas y limpiar cada elemento
    verifications = [v.strip().strip("'").strip('"') for v in verification_str.split(',')]
    return verifications

# 2. Crear una lista con todas las verificaciones
all_verifications = []
for verif_str in df_madrid['host_verifications'].dropna():
    all_verifications.extend(extract_verifications(verif_str))

# 3. Contar las ocurrencias usando Counter
from collections import Counter
verification_counts = Counter(all_verifications)

#Total tipos de verificaciones
print("Total tipos de host_verifications: ", len(verification_counts))

# 4. Mostrar los 10 más comunes
print("Top 10 verificaciones más comunes:")
for verification, count in verification_counts.most_common(10):
    print(f"{verification}: {count}")
# Out:
# Total tipos de host_verifications:  20
# Top 10 verificaciones más comunes:
# phone: 13187
# email: 12853
# reviews: 12058
# jumio: 7515
# facebook: 2704
# government_id: 2553
# work_email: 1150
# google: 877
# offline_government_id: 784
# manual_offline: 395

# %% [markdown]
# ## Conclusiones
#
# * ¿Qué opinas de AirBnB en Madrid?

# %%
"""
Conclusiones sobre AirBnB en Madrid:

1. Concentración de propietarios:
   - Hay una gran concentración de propiedades en pocas manos (algunos dueños tienen más de 200 propiedades)
   - La media es de 9.78 alojamientos por dueño, pero la mediana es 2, lo que indica una gran desigualdad

2. Precios:
   - El rango de precios es muy amplio (9€ - 7700€)
   - El precio mediano es 53€, bastante más bajo que la media de 69€
   - El 90% de los alojamientos están entre 18€ y 160€
   - Hay una clara segmentación por zonas (los códigos postales más caros rondan los 150€ de media)

3. Verificaciones y seguridad:
   - La mayoría de hosts tienen verificaciones básicas (teléfono y email)
   - Solo cerca del 56% tienen verificación por jumio (13,187 teléfono vs 7,515 jumio)
   - Muy pocos tienen verificación gubernamental (2,553)

4. Regulación:
   - Casi todos los alojamientos requieren licencia (13,320)
   - Sin embargo, muy pocos la tienen realmente (solo 249)
   - Esto sugiere un problema importante de regulación y cumplimiento normativo

En resumen: AirBnB en Madrid muestra signos de profesionalización del sector (muchos propietarios múltiples), 
con precios generalmente accesibles pero con problemas de regulación y verificación. El mercado parece estar 
dominado por grandes propietarios más que por el concepto original de economía colaborativa.
"""
